# %% [markdown]
# # 🎧 Batch Audio Transcription with `faster-whisper`
#
# This notebook will guide you through transcribing multiple `.mp3` or `.wav` files in a folder using the optimized [faster-whisper](https://github.com/guillaumekln/faster-whisper) model.

# %% [markdown]
# ## 🧰 Requirements
#
# Install the necessary libraries:

# %%
# %pip install faster-whisper ffmpeg-python
# Out:
# Requirement already satisfied: faster-whisper in ./.env/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: ffmpeg-python in ./.env/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: ctranslate2<5,>=4.0 in ./.env/lib/python3.11/site-packages (from faster-whisper) (4.4.0)
# Requirement already satisfied: huggingface-hub>=0.13 in ./.env/lib/python3.11/site-packages (from faster-whisper) (0.33.1)
# Requirement already satisfied: tokenizers<1,>=0.13 in ./.env/lib/python3.11/site-packages (from faster-whisper) (0.21.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in ./.env/lib/python3.11/site-packages (from faster-whisper) (1.22.0)
# Requirement already satisfied: av>=11 in ./.env/lib/python3.11/site-packages (from faster-whisper) (15.0.0)
# Requirement already satisfied: tqdm in ./.env/lib/python3.11/site-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: future in ./.env/lib/python3.11/site-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: setuptools in ./.env/lib/python3.11/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (65.5.0)
# Requirement already satisfied: numpy in ./.env/lib/python3.11/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.2.6)
# Requirement already satisfied: pyyaml<7,>=5.3 in ./.env/lib/python3.11/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.2)
# Requirement already satisfied: filelock in ./.env/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.env/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in ./.env/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper) (24.2)
# Requirement already satisfied: requests in ./.env/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.env/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./.env/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper) (1.1.5)
# Requirement already satisfied: coloredlogs in ./.env/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in ./.env/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.2.10)
# Requirement already satisfied: protobuf in ./.env/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (6.31.1)
# Requirement already satisfied: sympy in ./.env/lib/python3.11/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in ./.env/lib/python3.11/site-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.env/lib/python3.11/site-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.11/site-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.11/site-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.11/site-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2025.6.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.env/lib/python3.11/site-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# 📚 Imports
import os
import json
import time
from pathlib import Path
import subprocess
from faster_whisper import WhisperModel

# %% [markdown]
# ## 📁 Step 1: Set Up Your Folder Paths
#
# Prepare your folder with audio files and choose where to store your transcriptions.

# %%
# 🔧 Configuration

AUDIO_DIR = "audios"  # Folder with .mp3 or .wav files
OUTPUT_DIR = "transcripts"  # Folder to store .json outputs
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Model configuration
MODEL_SIZE = "large-v3"  # Options: tiny, base, small, medium, large-v3, etc.
LANGUAGE = "pt"  # e.g., 'en', 'pt', 'es', 'fr'
DEVICE = "cpu"  # 'cpu', 'cuda', 'mps', or 'auto'
COMPUTE_TYPE = "auto"  # 'float16', 'int8', 'auto', etc.

# %% [markdown]
# ## 🔄 Step 2: Utility Functions
#
# We’ll define a few helper functions for:
#
# - Converting MP3 → WAV (mono, 16kHz)
# - Resolving hardware configuration
# - Running the transcription

# %%
def convert_to_wav(input_path: str) -> str:
    """Converts any audio to mono WAV 16kHz."""
    output_path = Path(input_path).with_suffix(".wav")
    command = [
        "ffmpeg",
        "-y",
        "-i",
        input_path,
        "-acodec",
        "pcm_s16le",
        "-ac",
        "1",
        "-ar",
        "16000",
        str(output_path),
    ]
    subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return str(output_path)


def resolve_device(device_choice):
    if device_choice == "auto":
        import torch

        if torch.cuda.is_available():
            return "cuda"
        elif torch.backends.mps.is_available():
            return "mps"
        return "cpu"
    return device_choice


def resolve_compute_type(device, compute_choice):
    if compute_choice != "auto":
        return compute_choice
    if device in {"cuda", "mps"}:
        return "float16"
    return "int8"


def transcribe_file(model, file_path, language="en"):
    segments, _ = model.transcribe(
        file_path,
        beam_size=5,
        word_timestamps=False,
        vad_filter=True,
        language=language,
    )
    return [
        {"start": seg.start, "end": seg.end, "text": seg.text.strip()}
        for seg in segments
    ]

# %% [markdown]
# ## ⚙️ Step 3: Load the faster-whisper Model

# %%
device = resolve_device(DEVICE)
compute = resolve_compute_type(device, COMPUTE_TYPE)
print(f"Loading model on `{device}` with `{compute}` precision...")

model = WhisperModel(MODEL_SIZE, device=device, compute_type=compute)
# Out:
# Loading model on `cpu` with `int8` precision...

# %% [markdown]
# ## 🔁 Step 4: Transcribe All Files in the Folder
# This will process each `.mp3` or `.wav` file in the folder and save the output as a `.json` transcription.

# %%
for file_name in os.listdir(AUDIO_DIR):
    if not file_name.lower().endswith((".mp3", ".wav")):
        continue

    input_path = os.path.join(AUDIO_DIR, file_name)
    print(f"\n🔊 Processing: {file_name}")

    # Convert to 16kHz WAV
    wav_path = convert_to_wav(input_path)
    print("📥 Converted to WAV.")

    # Transcribe
    start = time.time()
    segments = transcribe_file(model, wav_path, language=LANGUAGE)
    print(f"📝 Transcribed in {time.time() - start:.2f}s.")

    # Save as JSON
    output_path = os.path.join(OUTPUT_DIR, Path(file_name).stem + ".json")
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(segments, f, ensure_ascii=False, indent=2)
    print(f"✅ Saved to: {output_path}")
# Out:
# 🔊 Processing: 59414b70-ed2b-43a9-9d61-09968aa13674_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 78.26s.
# ✅ Saved to: transcripts/59414b70-ed2b-43a9-9d61-09968aa13674_audio2.json
#
# 🔊 Processing: 7aed1441-334f-4556-b9b6-b69927b1ff4b_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 60.49s.
# ✅ Saved to: transcripts/7aed1441-334f-4556-b9b6-b69927b1ff4b_audio2.json
#
# 🔊 Processing: c4110d90-63b5-4afc-94e2-7089ac7ed712_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 141.25s.
# ✅ Saved to: transcripts/c4110d90-63b5-4afc-94e2-7089ac7ed712_audio2.json
#
# 🔊 Processing: 59414b70-ed2b-43a9-9d61-09968aa13674_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 34.75s.
# ✅ Saved to: transcripts/59414b70-ed2b-43a9-9d61-09968aa13674_audio1.json
#
# 🔊 Processing: 7aed1441-334f-4556-b9b6-b69927b1ff4b_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 32.98s.
# ✅ Saved to: transcripts/7aed1441-334f-4556-b9b6-b69927b1ff4b_audio1.json
#
# 🔊 Processing: c4110d90-63b5-4afc-94e2-7089ac7ed712_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 110.44s.
# ✅ Saved to: transcripts/c4110d90-63b5-4afc-94e2-7089ac7ed712_audio1.json
#
# 🔊 Processing: b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 17.44s.
# ✅ Saved to: transcripts/b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio1.json
#
# 🔊 Processing: b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 43.54s.
# ✅ Saved to: transcripts/b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio2.json
#
# 🔊 Processing: 50596932-b962-4c8b-aca4-7b00d5694d4e_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 44.76s.
# ✅ Saved to: transcripts/50596932-b962-4c8b-aca4-7b00d5694d4e_audio1.json
#
# 🔊 Processing: d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 19.45s.
# ✅ Saved to: transcripts/d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio1.json
#
# 🔊 Processing: 125eb62d-8ea5-41eb-9410-e63d644285a1_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 105.84s.
# ✅ Saved to: transcripts/125eb62d-8ea5-41eb-9410-e63d644285a1_audio2.json
#
# 🔊 Processing: b99b7aa0-0163-460b-875b-5261f7ec3291_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 80.78s.
# ✅ Saved to: transcripts/b99b7aa0-0163-460b-875b-5261f7ec3291_audio2.json
#
# 🔊 Processing: 8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 185.72s.
# ✅ Saved to: transcripts/8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio1.json
#
# 🔊 Processing: da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 88.28s.
# ✅ Saved to: transcripts/da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio1.json
#
# 🔊 Processing: d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 232.56s.
# ✅ Saved to: transcripts/d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio2.json
#
# 🔊 Processing: 50596932-b962-4c8b-aca4-7b00d5694d4e_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 207.01s.
# ✅ Saved to: transcripts/50596932-b962-4c8b-aca4-7b00d5694d4e_audio2.json
#
# 🔊 Processing: 125eb62d-8ea5-41eb-9410-e63d644285a1_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 103.34s.
# ✅ Saved to: transcripts/125eb62d-8ea5-41eb-9410-e63d644285a1_audio1.json
#
# 🔊 Processing: b99b7aa0-0163-460b-875b-5261f7ec3291_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 42.46s.
# ✅ Saved to: transcripts/b99b7aa0-0163-460b-875b-5261f7ec3291_audio1.json
#
# 🔊 Processing: 8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 117.37s.
# ✅ Saved to: transcripts/8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio2.json
#
# 🔊 Processing: da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 102.12s.
# ✅ Saved to: transcripts/da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio2.json
#
# 🔊 Processing: 7aed1441-334f-4556-b9b6-b69927b1ff4b_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 57.73s.
# ✅ Saved to: transcripts/7aed1441-334f-4556-b9b6-b69927b1ff4b_audio2.json
#
# 🔊 Processing: c4110d90-63b5-4afc-94e2-7089ac7ed712_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 343.27s.
# ✅ Saved to: transcripts/c4110d90-63b5-4afc-94e2-7089ac7ed712_audio2.json
#
# 🔊 Processing: 59414b70-ed2b-43a9-9d61-09968aa13674_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 1080.00s.
# ✅ Saved to: transcripts/59414b70-ed2b-43a9-9d61-09968aa13674_audio2.json
#
# 🔊 Processing: 7aed1441-334f-4556-b9b6-b69927b1ff4b_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 32.07s.
# ✅ Saved to: transcripts/7aed1441-334f-4556-b9b6-b69927b1ff4b_audio1.json
#
# 🔊 Processing: c4110d90-63b5-4afc-94e2-7089ac7ed712_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 598.70s.
# ✅ Saved to: transcripts/c4110d90-63b5-4afc-94e2-7089ac7ed712_audio1.json
#
# 🔊 Processing: 59414b70-ed2b-43a9-9d61-09968aa13674_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 33.76s.
# ✅ Saved to: transcripts/59414b70-ed2b-43a9-9d61-09968aa13674_audio1.json
#
# 🔊 Processing: b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 17.68s.
# ✅ Saved to: transcripts/b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio1.json
#
# 🔊 Processing: b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 53.06s.
# ✅ Saved to: transcripts/b8cceb60-1be2-4e0d-b8d0-98eb4ccffc92_audio2.json
#
# 🔊 Processing: 8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 1075.70s.
# ✅ Saved to: transcripts/8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio1.json
#
# 🔊 Processing: da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 83.53s.
# ✅ Saved to: transcripts/da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio1.json
#
# 🔊 Processing: b99b7aa0-0163-460b-875b-5261f7ec3291_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 75.04s.
# ✅ Saved to: transcripts/b99b7aa0-0163-460b-875b-5261f7ec3291_audio2.json
#
# 🔊 Processing: 125eb62d-8ea5-41eb-9410-e63d644285a1_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 152.43s.
# ✅ Saved to: transcripts/125eb62d-8ea5-41eb-9410-e63d644285a1_audio2.json
#
# 🔊 Processing: d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio1.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 1060.57s.
# ✅ Saved to: transcripts/d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio1.json
#
# 🔊 Processing: 50596932-b962-4c8b-aca4-7b00d5694d4e_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 40.79s.
# ✅ Saved to: transcripts/50596932-b962-4c8b-aca4-7b00d5694d4e_audio1.json
#
# 🔊 Processing: 8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 627.43s.
# ✅ Saved to: transcripts/8941bfd6-3a4c-4cf4-a3d2-2f875586bc2d_audio2.json
#
# 🔊 Processing: da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 106.49s.
# ✅ Saved to: transcripts/da6e2d9c-d629-4dd8-b8a6-c28696c6c506_audio2.json
#
# 🔊 Processing: b99b7aa0-0163-460b-875b-5261f7ec3291_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 39.29s.
# ✅ Saved to: transcripts/b99b7aa0-0163-460b-875b-5261f7ec3291_audio1.json
#
# 🔊 Processing: 125eb62d-8ea5-41eb-9410-e63d644285a1_audio1.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 98.30s.
# ✅ Saved to: transcripts/125eb62d-8ea5-41eb-9410-e63d644285a1_audio1.json
#
# 🔊 Processing: 50596932-b962-4c8b-aca4-7b00d5694d4e_audio2.wav
# 📥 Converted to WAV.
# 📝 Transcribed in 207.16s.
# ✅ Saved to: transcripts/50596932-b962-4c8b-aca4-7b00d5694d4e_audio2.json
#
# 🔊 Processing: d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio2.MP3
# 📥 Converted to WAV.
# 📝 Transcribed in 223.18s.
# ✅ Saved to: transcripts/d1ecd300-2dc4-4c14-91ae-36aa02c44fee_audio2.json

# %% [markdown]
# ## ✅ Done!
#
# You can now find your transcriptions in the `transcripts/` folder.
#
# Each `.json` file will look like:
#
# ```json
# [
#   {
#     "start": 0.0,
#     "end": 2.56,
#     "text": "Hello, how can I help you?"
#   },
#   ...
# ]
